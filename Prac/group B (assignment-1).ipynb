# %%
#Perform the following operations using Python on the Facebook metrics data sets

# %%
import pandas as pd;

# %%
data=pd.read_csv('./fb.csv')

# %%
data.shape
# Out:
# (500, 19)

# %%
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
#a. Create data subsets

# %%
df=data.iloc[1:20]

# %%
df.shape
# Out:
# (19, 19)

# %%
df1=data.loc[20:100,['Type','like','share','comment']]

# %%
df1
# Out:
#        Type   like  share  comment
# 20    Photo   66.0   12.0        3
# 21    Photo    0.0    0.0        0
# 22     Link   16.0    2.0        0
# 23    Photo   72.0   24.0        0
# 24   Status   99.0   19.0        3
# ..      ...    ...    ...      ...
# 96    Photo   51.0   11.0        3
# 97    Photo  115.0   26.0        1
# 98   Status  310.0   61.0        7
# 99    Photo  328.0   90.0       12
# 100   Photo    0.0    0.0        0
#
# [81 rows x 4 columns]

# %%
df2=data.iloc[20:40,[1,4,5,6,7]]

# %%
df2
# Out:
#       Type  Post Weekday  Post Hour  Paid  Lifetime Post Total Reach
# 20   Photo             1          3   0.0                       2848
# 21   Photo             7         10   0.0                       1384
# 22    Link             7         10   0.0                       3454
# 23   Photo             7          3   0.0                       2723
# 24  Status             6         10   0.0                       8488
# 25  Status             6          3   0.0                       8284
# 26  Status             5         11   0.0                      19552
# 27   Photo             5          3   0.0                       2478
# 28   Photo             5          3   0.0                       9560
# 29   Video             4         11   1.0                      36208
# 30   Photo             4          2   0.0                       4940
# 31   Photo             3         10   0.0                       1683
# 32   Photo             3          3   0.0                       5280
# ...

# %%
df3=data[(data['like']>100) & (data['comment']>20)]

# %%
df3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 28             138895   Photo         2          12             5          3
# 30             138895   Photo         2          12             4          2
# 51             138329   Photo         1          11             1          3
# 101            137020   Photo         2          10             4          3
# 105            137020   Photo         1          10             2          4
# 142            136013  Status         2          10             3          2
# 150            135713   Photo         1          10             6          4
# 152            135713   Photo         2          10             5          4
# 158            135700   Photo         2           9             1         10
# 162            135617   Photo         3           9             6         10
# ...

# %%
#b. Merge Data

# %%
df4=pd.merge(df3,df2,on="Type")

# %%
df4
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday_x  \
# 0              139441   Photo         2          12               2
# 1              139441   Photo         2          12               2
# 2              139441   Photo         2          12               2
# 3              139441   Photo         2          12               2
# 4              139441   Photo         2          12               2
# ..                ...     ...       ...         ...             ...
# 396            135195  Status         2           9               1
# 397            135195  Status         2           9               1
# 398            135195  Status         2           9               1
# 399            135195  Status         2           9               1
# 400            126424   Video         1           6               2
#
#      Post Hour_x  Paid_x  Lifetime Post Total Reach_x  \
# 0             10     1.0                        50128
# ...

# %%
#c. Sort Data

# %%
df3.sort_values(by=['share'],ascending='false')
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 268            128032   Photo         1           7             5          3
# 30             138895   Photo         2          12             4          2
# 228            131728   Photo         2           7             4          3
# 172            135195  Status         2           9             1         10
# 51             138329   Photo         1          11             1          3
# 272            127082   Photo         1           7             3          3
# 288            126141   Photo         1           6             4         12
# 158            135700   Photo         2           9             1         10
# 150            135713   Photo         1          10             6          4
# 338            119198   Photo         3           5             5         10
# 277            126424   Video         1           6             2         13
# ...

# %%
#d. Transposing Data

# %%
df1_transposed=df3.T

# %%
df1_transposed
# Out:
#                                                        3       28      30   \
# Page total likes                                    139441  138895  138895
# Type                                                 Photo   Photo   Photo
# Category                                                 2       2       2
# Post Month                                              12      12      12
# Post Weekday                                             2       5       4
# Post Hour                                               10       3       2
# Paid                                                   1.0     0.0     0.0
# Lifetime Post Total Reach                            50128    9560    4940
# Lifetime Post Total Impressions                      87991   18264    9390
# Lifetime Engaged Users                                2211     973     385
# Lifetime Post Consumers                                790     559     306
# ...

# %%
#e. Shape and reshape Data

# %%
series_obj=pd.Series(df1['like'])

# %%
arr=series_obj.values

# %%
arr.reshape((9,9))
# Out:
# array([[ 66.,   0.,  16.,  72.,  99.,  88., 412., 100., 523.],
#        [143., 107.,  27., 155.,  98.,  56., 172.,  96.,  76.],
#        [227.,  44., 216., 187.,  26.,  29.,  47.,  57., 174.],
#        [ 18.,  77.,  12.,  48., 285., 202.,  64.,  66.,  65.],
#        [164.,  40.,  76., 139., 101., 144., 179., 219.,  60.],
#        [ 77.,  48., 697.,  53.,  84., 146., 449., 226., 172.],
#        [ 99., 411.,   0.,  85.,  56.,  29.,  86., 370., 190.],
#        [101.,  99., 140., 130., 270.,  30., 107., 331.,  78.],
#        [301., 111., 124., 153.,  51., 115., 310., 328.,   0.]])
