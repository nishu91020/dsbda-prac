# %%
#Perform the following operations using Python on the Air quality and Heart Diseases data sets

# %%
import pandas as pd

# %%
data=pd.read_csv('./airquality.csv')

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
#a. Data cleaning

# %%
#empty row cells
new_df=data.dropna()
#If you want to change the original DataFrame, use the inplace = True argument:
new_df1=data.dropna(inplace=True)
new_df1
# fill null values with some default value
new_df2=data.fillna(100,inplace=True)
new_df3=data['Solar.R'].fillna(100,inplace=True)
new_df3
#backfill/pad
A=data.fillna(method='backfill')
B=data.fillna(method='pad')
A
B
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 6             7   23.0    299.0   8.6    65      5    7
# ..          ...    ...      ...   ...   ...    ...  ...
# 147         148   14.0     20.0  16.6    63      9   25
# 148         149   30.0    193.0   6.9    70      9   26
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [111 rows x 7 columns]

# %%
#data of wrong format
data['Ozone']=pd.to_numeric(data['Ozone'])
data
#removing rows
df=data
df.dropna(subset=['Ozone'],inplace=True)
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 6             7   23.0    299.0   8.6    65      5    7
# ..          ...    ...      ...   ...   ...    ...  ...
# 147         148   14.0     20.0  16.6    63      9   25
# 148         149   30.0    193.0   6.9    70      9   26
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [111 rows x 7 columns]

# %%
for x in df.index:
  if df.loc[x, "Solar.R"] > 200:
    df.drop(x, inplace = True)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 7             8   19.0     99.0  13.8    59      5    8
# 8             9    8.0     19.0  20.1    61      5    9
# 14           15   18.0     65.0  13.2    58      5   15
# 17           18    6.0     78.0  18.4    57      5   18
# 19           20   11.0     44.0   9.7    62      5   20
# 20           21    1.0      8.0   9.7    59      5   21
# 22           23    4.0     25.0   9.7    61      5   23
# 23           24   32.0     92.0  12.0    61      5   24
# 27           28   23.0     13.0  12.0    67      5   28
# 37           38   29.0    127.0   9.7    82      6    7
# 43           44   23.0    148.0   8.0    82      6   13
# 46           47   21.0    191.0  14.9    77      6   16
# 48           49   20.0     37.0   9.2    65      6   18
# ...

# %%
#b. Data integration

# %%
#------------skip------------------

# %%
#c. Data transformation

# %%
from sklearn.model_selection import train_test_split
train,test=train_test_split(data,test_size=0.20)

# %%
len(train)
# Out:
# 42

# %%
len(test)
# Out:
# 11

# %%
from sklearn.preprocessing import StandardScaler
#removes the mean and scales each feature/variable to unit variance.

# %%
scaler=StandardScaler()

# %%
B=scaler.fit_transform(data)

# %%
pd.DataFrame(B).describe()
# Out:
#                   0             1             2             3             4  \
# count  5.300000e+01  5.300000e+01  5.300000e+01  5.300000e+01  5.300000e+01
# mean  -8.379042e-18  9.216946e-17 -1.225435e-16 -2.199498e-16 -3.747330e-16
# std    1.009570e+00  1.009570e+00  1.009570e+00  1.009570e+00  1.009570e+00
# min   -1.720737e+00 -1.220374e+00 -1.553967e+00 -2.044635e+00 -1.911722e+00
# 25%   -8.300807e-01 -7.456594e-01 -9.078187e-01 -7.677858e-01 -5.984851e-01
# 50%    1.848532e-01 -3.500643e-01 -1.040735e-01 -1.293609e-01  7.624014e-03
# 75%    8.683801e-01  4.806854e-01  1.093664e+00  5.090640e-01  6.137332e-01
# max    1.406917e+00  2.537780e+00  1.440378e+00  2.757430e+00  1.825951e+00
#
#                   5             6
# count  5.300000e+01  5.300000e+01
# mean   2.346132e-16 -7.541138e-17
# std    1.009570e+00  1.009570e+00
# min   -1.457301e+00 -1.625490e+00
# 25%   -8.082508e-01 -9.353621e-01
# 50%    4.898490e-01  9.982983e-02
# 75%    1.138899e+00  7.899578e-01
# ...

# %%
#normalization min_max

# %%
from sklearn.preprocessing import MinMaxScaler
#Transform features by scaling each feature to a given range.

# %%
scaler=MinMaxScaler()

# %%
A=scaler.fit_transform(B)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-05ae881e5a57> in <module>
# ----> 1 A=scaler.fit_transform(B)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     361         # Reset internal state before fitting
#     362         self._reset()
# --> 363         return self.partial_fit(X, y)
#     364
#     365     def partial_fit(self, X, y=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     394
# ...

# %%
pd.DataFrame(A).describe()
# Out:
#                0          1          2          3          4          5  \
# count  53.000000  53.000000  53.000000  53.000000  53.000000  53.000000
# mean    0.550169   0.324727   0.518967   0.425783   0.511474   0.561321
# std     0.322788   0.268634   0.337159   0.210237   0.270106   0.388864
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.284768   0.126316   0.215789   0.265896   0.351351   0.250000
# 50%     0.609272   0.231579   0.484211   0.398844   0.513514   0.750000
# 75%     0.827815   0.452632   0.884211   0.531792   0.675676   1.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#                6
# count  53.000000
# mean    0.471069
# std     0.292575
# min     0.000000
# 25%     0.200000
# 50%     0.500000
# 75%     0.700000
# max     1.000000

# %%
#Binarization

# %%
from sklearn.preprocessing import Binarizer
#discretization of continious values

# %%
bin=Binarizer(threshold=0.5)

# %%
A=bin.fit_transform(B)

# %%
pd.DataFrame(A).describe()
# Out:
#                0          1          2          3          4          5  \
# count  53.000000  53.000000  53.000000  53.000000  53.000000  53.000000
# mean    0.396226   0.226415   0.358491   0.301887   0.377358   0.301887
# std     0.493793   0.422516   0.484146   0.463470   0.489364   0.463470
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     1.000000   0.000000   1.000000   1.000000   1.000000   1.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#                6
# count  53.000000
# mean    0.358491
# std     0.484146
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     1.000000
# max     1.000000

# %%
#label encoder

# %%
from sklearn.preprocessing import LabelEncoder
#converting the labels into a numeric form so as to convert them into the machine-readable form.

# %%
l=LabelEncoder()

# %%
B=l.fit_transform(data['Ozone'])
B
# Out:
# array([23, 21,  7, 12,  4, 11,  2,  6,  0,  1, 20, 16, 18, 16, 14, 13,  7,
#         8, 28, 33, 17,  3, 32, 10, 13, 26, 22,  5, 10, 24, 29, 15, 27, 16,
#        24,  5, 33, 35, 31, 30, 34, 25, 20,  5,  8,  8, 16, 21,  3,  9, 19,
#         9, 11], dtype=int64)

# %%
#d. Error correcting

# %%
#fill null values with mean/median/mode
x=data['Solar.R'].mean()
new_df4=data.fillna(x)
new_df4
x1=data['Solar.R'].mode()
new_df5=data.fillna(x1)
new_df5
x2=data['Solar.R'].median()
new_df6=data.fillna(x2)
new_df6
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 7             8   19.0     99.0  13.8    59      5    8
# 8             9    8.0     19.0  20.1    61      5    9
# 14           15   18.0     65.0  13.2    58      5   15
# 17           18    6.0     78.0  18.4    57      5   18
# 19           20   11.0     44.0   9.7    62      5   20
# 20           21    1.0      8.0   9.7    59      5   21
# 22           23    4.0     25.0   9.7    61      5   23
# 23           24   32.0     92.0  12.0    61      5   24
# 27           28   23.0     13.0  12.0    67      5   28
# 37           38   29.0    127.0   9.7    82      6    7
# 43           44   23.0    148.0   8.0    82      6   13
# 46           47   21.0    191.0  14.9    77      6   16
# 48           49   20.0     37.0   9.2    65      6   18
# ...

# %%
#e. Data model building

# %%
from sklearn.linear_model import LinearRegression

# %%
X=data['Ozone'].values

# %%
X=X.reshape(-1,1)

# %%
X_train,X_test=train_test_split(X,test_size=0.20)

# %%
Y=data['Temp'].values

# %%
Y=Y.reshape(-1,1)

# %%
Y_train,Y_test=train_test_split(Y,test_size=0.20)

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)

# %%
X_pred=model.predict(X_train)

# %%
model.score(X_test,Y_pred)*100
# Out:
# 100.0

# %%
model.predict([[128]])
# Out:
# array([[73.83220171]])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X_train, Y_train, color="green")   
plt.plot(Y_test, Y_pred, color="red")
